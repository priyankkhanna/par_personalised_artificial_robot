# %%
#pip install rasa

# %%
import rasa

# %%
rasa.__dict__
# Out:
# {'__name__': 'rasa',
#  '__doc__': None,
#  '__package__': 'rasa',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x226d719e760>,
#  '__spec__': ModuleSpec(name='rasa', loader=<_frozen_importlib_external.SourceFileLoader object at 0x00000226D719E760>, origin='C:\\Users\\priya\\anaconda3\\lib\\site-packages\\rasa\\__init__.py', submodule_search_locations=['C:\\Users\\priya\\anaconda3\\lib\\site-packages\\rasa']),
#  '__path__': ['C:\\Users\\priya\\anaconda3\\lib\\site-packages\\rasa'],
#  '__file__': 'C:\\Users\\priya\\anaconda3\\lib\\site-packages\\rasa\\__init__.py',
#  '__cached__': 'C:\\Users\\priya\\anaconda3\\lib\\site-packages\\rasa\\__pycache__\\__init__.cpython-38.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
#   '__loader__': _frozen_importlib.BuiltinImporter,
# ...
